# %% [markdown]
# <a href="https://colab.research.google.com/github/sumam121/Wine-Quality-Prediction/blob/main/major_project_8th_oct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv("/content/Red_wine__(1).csv",sep=',')
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#Check null values

df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
#Identify and handle missing values
# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    1
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
#Filling null values with mean of the numerical data
mean_total_sulfur_dioxide=df['total sulfur dioxide'].mean()
mean_pH=df['pH'].mean()
mean_quality=df['quality'].mean()

# %%
mean_total_sulfur_dioxide=round(mean_total_sulfur_dioxide,1)

mean_total_sulfur_dioxide
# Out:
# 46.4

# %%
mean_pH=round(mean_pH,2)
mean_quality=round(mean_quality,1)

# %%
df['total sulfur dioxide']=df['total sulfur dioxide'].fillna(mean_total_sulfur_dioxide)
df['pH']=df['pH'].fillna(mean_pH)
#df['quality']=df['quality'].fillna(mean_quality)

# %%
df= df.dropna(axis=0,how='any')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **DATA ANALYSIS**

# %%
#Exploratory Data Analysis (EDA)
#Univariate Analysis

# %%
df['quality'].value_counts()
# Out:
# 5.0    680
# 6.0    638
# 7.0    199
# 4.0     53
# 8.0     18
# 3.0     10
# Name: quality, dtype: int64

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256100     0.671958
# volatile acidity          -0.256100          1.000000    -0.552123
# citric acid                0.671958         -0.552123     1.000000
# residual sugar             0.114783          0.001891     0.143702
# chlorides                  0.093689          0.061419     0.203810
# free sulfur dioxide       -0.153860         -0.010211    -0.061425
# total sulfur dioxide      -0.112834          0.076972     0.034774
# density                    0.668149          0.021747     0.365586
# pH                         0.027456         -0.046005     0.007782
# sulphates                  0.182953         -0.260636     0.312357
# alcohol                   -0.061783         -0.201849     0.109241
# quality                    0.123987         -0.390258     0.225867
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.groupby("quality").mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3.0           8.360000          0.884500     0.171000        2.635000
# 4.0           7.779245          0.693962     0.174151        2.694340
# 5.0           8.167500          0.576846     0.244044        2.528750
# 6.0           8.347179          0.497484     0.273824        2.477194
# 7.0           8.872362          0.403920     0.375176        2.720603
# 8.0           8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3.0       0.122500            11.000000             24.900000  0.997464
# 4.0       0.090679            12.264151             36.245283  0.996542
# 5.0       0.092754            16.992647             56.465294  0.997103
# 6.0       0.084956            15.711599             40.869906  0.996615
# 7.0       0.076588            14.045226             35.020101  0.996104
# ...

# %%
sns.countplot(x='quality',data=df)
plt.show()

# %%
for label in df.columns[:-1]:
# for label in ['alcohol']:
    plt.scatter(df['quality'], df[label])
    plt.title(label)
    plt.xlabel('quality')
    plt.ylabel(label)
    plt.rcParams['figure.figsize'] = [5, 5]

    plt.show()

# %%
df.hist(bins=100, figsize=(10,12))
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation between the columns')
plt.show()
